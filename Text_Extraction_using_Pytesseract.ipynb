# %%
import cv2

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.6/dist-packages (0.3.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from pytesseract) (7.0.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image 
import pytesseract as pt 
import os 
      
def main(): 
    # path for the folder for getting the raw images 
    path ="drive/MyDrive/jpg_images"
  
    # link to the file in which output needs to be kept 
    fullTempPath ="drive/MyDrive/jpg_images/outputFile.txt"
  
    # iterating the images inside the folder 
    for imageName in os.listdir(path): 
        inputPath = os.path.join(path, imageName) 
        img = Image.open(inputPath) 
  
        # applying ocr using pytesseract for python 
        text = pt.image_to_string(img) 
  
        # saving the  text for appending it to the output.txt file 
        # a + parameter used for creating the file if not present 
        # and if present then append the text content 
        file1 = open(fullTempPath, "a+") 
  
        # providing the name of the image 
        file1.write(imageName+"\n") 
  
        # providing the content in the image 
        file1.write(text+"\n") 
        file1.close()  
  
    # for printing the output file 
    file2 = open(fullTempPath, 'r') 
    print(file2.read()) 
    file2.close()         
  
  
if __name__ == '__main__': 
    main()
# Out:
# winchesterP-34.jpg
# Butte
#
# LEibibtiuiwBwitiiaiiGieiEui®lls @ &@
#
# BIOGRAPHICAL REGISTER
#
# iee0 BIOGRAPHICAL REGISTER
#
# (de) Dunstaple, William (/l, by 1271, by 1303) (cont.)
# Father of William de Dunstap(e)le I, from whom he
# cannot always be distinguished. Possibly related to
# Henry de Donestaple.
#
# For possible references, cf. his son. Spicer, draper.
# Alderman ?of Gold Street 1286 (Hall Law Merchant
# iii, 9-10), citizen by 1286-9, bailiff 1 (1300-1).
#
# de Dunstaple, William (fl. 1271, d. c. 1312), v. William
# de Dunstap(e)le II.
#
# de Dunstaple, William (fl. by c. 1312, by 1346), v. William
# de Dunstap(e)le IIL.
#
# Dunster(re), Thomas (fl. 1409-46). 147, 153A and C,
# 158, 349, 357, 2643. Married (by 1432) Alice (CR).
#
# Inhabited Gold Street aldermanry in 1430 and
# later. Draper; bought cloth 1428 (CRB); traded in
# hides ?1416, traded in wine and iron powder for John
# Choude 1426 (CRB); imported wine and com through
# Southampton 1427 (E122/184/3). Subsidy 6s. 8d.
# (1430), 16d. (1435), 12d. (1436), 10d. (1446). Alder-
# man of Jewry Street 1409-10, bagman 1409-11,
# 1416-18, chamberlain 1417-19, bagman 1418-19,
# warden of the common postern 1419-20, chamber-
# lain 1421-2, bagman 1421-2 (CA); MP 1427, 1429-
# 30; auditor for commons 1431 (CR); bagman 1432-
# 3 (CA).
#
# ~~, Alice wife of (fl. 1432).
#
# de Dunstighle, Peter, v. Peter (de) Donstighele alias Peter
# le Gayler alias Peter atte Gaiole.
#
# Dunstile, Peter, v. Peter (de) Donstighele alias Peter le
# Gayler alias Peter atte Gaiole.
#
# de Dunstyghele, Peter, v. Peter (de) Donstighele alias
# Peter le Gayler alias Peter atte Gaiole.
#
# de Dunstynghele, Peter, v. Peter (de) Donstighele alias
# Peter le Gayler alias Peter atte Gaiole.
#
# de Duntune, Robert (fl. 1222-48). ?Part 27/30-2.
#
# Dunwatere, Alice, v. wife of Henry Woderyng.
#
# Durant, Henry (fl. 1320). Part 620, 622-3. Son of
# Durant de Inkepen(ne).
#
# Durant, John (fl. by 1544). 727. Probably related to Wil-
# liam Durant(e).
#
# Durant, Thomas (fl. 1320s, 1343-4). Part 826.
#
# Durant(e), William (fl. 1537-62). From his ?relative
# John Durant: 727. Also held: part 800.
#
# Member of Hyde Abbey fraternity (LVH, 176-92).
#
# Dureford, John (/7. 1415-27). 834D, part 942.
#
# ?Miller.
#
# Dureward, Cristina (fl. 1280, by 1288). 2634. Sister of
# Roger of Droxford and probably related to William
# Dur(e)ward, Ralph Doreward, Clarice Doreward, and
# Alexander Doreward.
#
# Dur(e)ward, William, of Upton (fl. 1280; ?d. by 1311).
# Doreward. 634, part 644. Father of Alexander Dore-
# ward and Ralph Doreward. Probably related to Cris-
# tina Dureward, Clarice Doreward, and Roger of
#
# Droxford.
#
# Durgate, John (fl. 1470-1). Part 288.
#
# Durham, bishop of, v. sub INSTITUTIONS.
#
# Durneford, Henry (fl. by 1394). Part 1104.
#
# de Durneford, Benedict (fl. 1325). Part 618-19.
#
# de Durnegate, Florence (?d. by 1304). From her ?rela-
# tive Henry de Durnegate: 293. Possibly daughter of
# Alexander de Merewell(e). Mother of Cristina.
#
# ~~, Cristina daughter of (fl. by 1304). 293.
#
# de Durnegate, Henry (fl. 1256, 21294). 116, 293, 447,
# 736-40, ?part 1021, part 1107. Probably related to
# Alice de Dernegate and Florence de Durnegate.
#
# Licence to export 20 sacks of wool except to
#
# Flanders 1273 (Cal Pat R 1272-81, p. 38). Trespass
# on community 1274 (Cal Close R 1272-9, p. 128).
# Imprisoned and fined 1000 marks for having con-
# cealed goods of Benedict of Winchester 1281 (Cal
# Fine R 1272-1307, p. 144). Elector of city jury
# 1256 (Just1/778); bailiff c.1266-73; warden of Win-
# chester Jews 1270 (Cal Pat R 1266-72, p. 417);
# bailiff c. 1276-7.
#
# de Durnegate, Reyner alias Reyner de Hoghton (fl.
# 1288-1305). de Hocton. Part 330, part 444-5, ?part
# 976, 980, Probably related to William Reyner(e).
#
# Tapener. Supplied drink to royal household temp.
# Edward I (E101/370/20/17).
#
# Durward, William, v. William Dur(e)ward.
#
# Dusing’, Samson (fl. 1266). Part 736-40. Married (by
# 1266) Alice.
#
# ~~, Alice wife of (/l. 1266).
#
# Dutton, Cristina (fl. 1452-4). Part 681. Probably related
# to Robert Dutton.
#
# Dutton, John (fl. 1421; d. by 1453-4, ?by 1435),
# v. John Dutton(e) I.
#
# Dutton, John II (ff. 1436-46). From his father John
# Dutton(e) I: 193. Also held: 192. Possibly related to
# William Dutton.
#
# Inhabited 192-3. Saddler. Subsidy 3s, (1436),
# 6s. 8d. (1446). Mayor 1444-5, MP 1450, mayor
# 1453-4. Difficult to distinguish from his father.
#
# Dutton, John (/1. 1489). 641.
#
# Dutton, Robert (fl. 1438-59). From his ?relative Cristina
# Dutton: part 681. Also held: 679, ?part 694-7, 702.
#
# Inhabited High Street aldermanry. Smith 1438-9;
# innkeeper 1454-5 (CR); had iron carted from South-
# ampton 1443-4 (Brokage); made iron bonds and
# hooks 1446-7 (CA); ale offences 1454-5 (CR). Sub-
# sidy 3s, (1446). Bailiff 2 (1447-8), bailiff 1 (1449-
# 50); chamberlain 1452-4 (CA).
#
# Dutton, William (fl. 1446-78). ?193, part 622-3. Pos-
# sibly related to John Dutton(e) I and John Dutton II.
#
# ?Inhabited ?193. Sold bawdrick 1476-7 (CA).
# Subsidy 12d. (1446). Bagman 1469-72, 1473-4,
# 1476-8 (CA).
#
# Dutton(e), John I (fl. 1421; d. by 1453-4, by 1435).
# 192, 193, 649. Married (by 1422) Agnes ?widow of
#
#
#
#
#
# John Estbury. Father of John Dutton II. Possibly
# related to William Dutton.
#
# Inhabited High Street (?near 218) 1430. Saddler;
# entered liberty of city 1421 (Wedgwood, 289); sald
# shoes 1433 (CRB). Subsidy 13s, 4d. (1430). Citizen
# 1422; constable 1422 (Wedgwood, 289); bailiff 1
# (1429-30); cofferer 1432 (CR); MP 1433. Not listed
# in 1435 subsidy and so perhaps d. by then. By 1453-
# 4 remembered as a benefactor of the city (v. SJH)
# Difficult to distinguish from his son (cf. confusion in
# Wedgwood).
#
# ~™, Agnes wife of, v. Agnes widow of Joh:
# Dwelyon, Gyleham (ff. 1459-73). Part ce earn
#
# Fuller.
#
# Dyar, Henry (ff. 1482-5). Part 622-3,
# — rtiy (fl. 1430-6). Dygher. Part 479-81,
#
# nhabited part 479-81. Subsid:
#
# (1435), 3d. (1436). ne ree
# Dyare, John (f7. 1489-90). 461.
# Dyers, v. Adam,
# Azo,
# Drew,
# Geoffrey le Tainturor,
# Hugh atte Quabbe alias i
# Hugh Blak . Blac, rie see
# John,
# Walter,
# William le Tenterer alias William the dyer.
# Dyer, Hamo (fl. by 1407). 472.
# Fuller. Citizen by 1407.
# Dyer, James (fl. c.1497). Part 486.
# *James Broune.
# Dyer, John (fl. 1483-5). Part 645. Possibly related to
# Alice widow of John Dyer (d. by 1458)
# Dyer, John (d. by 1458), v. following.
# ~~, Alice widow of (fl. 1458-61). Part 645. Possibly re-
# lated to John Dyer (fl. 1483-5).
# Dyer, John (fl. 1438-62), v. John Dyer(e).
# Dyer, William (fl. 1409-17). 547,
# Bought cloth at Salisbury 1409 (CRB).
# Dyer, William (ff. 1515-16). Part 681.
# Dyer(e), John (fl. 1438-62). Parts 238/678, 385,
# et ego v. Nicholas le Deyghare.
# le Dyghare, Walter alias Walter
# 1317). Part 423, Ce
# Dygher, John, v. John Dyare (fl. 1430-6).
# le Dygher, Hamo, v. Hamo de Alresford, alias.
# Dyk’, Thomas, v. Thomas Dykes.
# Dykef(f)yn, Walter (/. by 1363, by 1404), 224-5, 226
# 21011. a
# Chaplain.
# Dykefyn, Richard, v. Richard Dykevyn.
# Dykefyn, Walter, v. Walter Dykef(f)yn.
# Dykes, Thomas (fl. by 1319; d. by 1341). Dyk’. 728-9
# Married (by 1321) Agnes. ;
#
# 1221
#
# Inhabited city (?High Str i
# ‘ae ty (?High Street). Subsidy 18d. (1327),
#
# ~™, Agnes wife of (1. by 1321).
#
# ~~, executor of (ff. by 1341). 728.
#
# Dykevyn, Agnes, v. sister of Richard Dykevyn.
#
# Dykevyn, Richard (1. 1285-1312). Dikevin, Dykefyn.
# Part 989, 21010, ?part 1012, 71014. Brother of
# Agnes Dykevyn. Possibly related to Cristina Dikvyn.
#
# ~~, Agnes Dykevyn sister of (/1. 1285-1300). From her
# ?relative Cristina Dikvyn: ?part 1012. Married (by
# 1285-1300) Richard de Tupenham.
#
# Dymand, Robert, v, Robert Dymaund(e) alias Robert
# the baker alias Robert called Dymaunde.
#
# Dymars, John, v. John Dy(s)mars.
#
# Dymars, Maud (fl. by 1310). Part 63-8.
#
# Dymaund, Robert, v, Robert Dymaund(e) alias Robert
# the baker alias Robert called Dymaunde.
#
# Dymaund, Walter (fl. 1381). 677. Related to Robert
# Dymaund(e) alias Robert the baker alias Robert
# called Dymaunde.
#
# Dymaund(e), Robert alias Robert the baker alias Robert
# called Dymaunde (ff, by 1300; d. by 1344). Dymand.
# 64-5, 223, 224-5, part 238/678, ?part 659, 660, part
# 661-5, 677, ?688, ?part 690, 2920. Married (by
# 1300) Agnes. Related to Walter Dymaund.
#
# Inhabited 660. Baker; lent Crown share 100 marks
# c.1340 (Cal Pat R 1338-40, p. 450). Subsidy 18d.
# (1327), 13s, 4d. (1332), 15s. (1340). Citizen 1315-
# 16, bailiff 1 (1330-1).
#
# ~ ™, Agnes wife of (fl. by 1300, by 1334).
#
# ~™, executors of (7. 1344, by 1345). ?Part 690, 2920
#
# Dymmok, John (fl, 1414). 269. ts
#
# ?Innkeeper.
#
# Dyneley, Robert (d. by 1422), v. following.
#
# ~~, Margaret Dynely widow of (/1. 1422). 541. Mother
# of Robert Dynely.
#
# Dynely, Margaret, v. widow of Robert Dyneley.
#
# Dynely, Robert (f1. 1422). 541. Son of Robert Dyneley
# and Margaret Dynely.
#
# Dynggele, Robert (d. by 1397). 102.
#
# Dynyton, John, v, John Denyton called Scherer alias
# John Sherere.
#
# Dypar, John (fl. 1500). 1003.
#
# Dyryk, John (fl. 1495-6). 290.
#
# Dyschar, John, v. John Discher.
#
# Dy(s)mars, John (fl, 1340; 2d. by 1364). 416, part 420
# ?659. Married (by 1344) Alice. Father of Nicholas
# Dysmars.
#
# Inhabited ?659. Subsidy 8d, (1340).
#
# ~™, Alice wife of (71. by 1344, by 1348).
#
# Dysmars, Nicholas (fl. by 1364). From his father John
# Dy(s)mars: 416.
#
# Dysshere, Joan (fl. 143 7-41). Part 622-3. Probably re-
# lated to John Dysshere and Margaret Dysshere.
#
# Dysshere, John (/7. 1446-60). From his ?relative Margaret
#
# winchesterP-121.jpg
#
#
# 1394 BIOGRAPHICAL REGISTER
#
# de Wyk, William (cont. )
#
# 1381) Joan wife and widow of John de Oxenford
# (d. by 1381).
#
# ~™, Joan wife of, v. wife and widow of John de Oxen-
# ford (d. by 1381).
#
# Wyk(e), John (fl. 1496; d. 1511). Mills at Coytebury,
# 697, 702, part 800, 914-23.
#
# ?Fuller.
#
# ~~, widow of (fl. 1511-12). From her husband: part
# 800.
#
# Wyke, Richard (fl. 1336, by 1364), v. Richard (de)
# Wyke.
#
# Wyke, Richard I (fl. 1337-88). 5/245-6, AF3. Probably
# father of Richard Wyke II. Married (by 1349) Agnes.
# Later married (by 1388) Cristina wife and widow of
# Thomas (de) Medmenham.
#
# Dyer. Bailiff 2 (1347-8).
#
# ~~, Agnes wife of (fl. 1349; d. by 1388).
#
# ~™, Cristina wife of, v. wife and widow of Thomas (de)
# Medmenham.
#
# Wyke, Richard II, junior (fl. by 1349, 1397). Wike. Part
# 63-8, 420, 548. Probably son of Richard Wyke I.
# Married (by 1349) Cristina daughter of Thomas (de)
# Medmenham. Later married (by 1391) Isabel. Possibly
# related to Joan Wyg and Isabel Wygge.
#
# Inhabited 420. ?Dyer; brewer 1373-80 (CR); ale
# offences 1351-97 (CR). Collector 1357-8 (CA); citi-
# zen 1390.
#
# ~™, Cristina wife of, v. daughter of Thomas (de) Med-
# menham.
#
# ~~, Isabel wife of (7. by 1391).
#
# Wyke, William (/2. 1454-64). Part SJH.
#
# Warden of SJH.
#
# de Wyke, John (fl. by 1320, 1330, ?1349-50). 265 west
# Cc.
#
# Clerk by 1320 and 1330 (CR). A man of this name
# was bailiff 1 (1349-50).
#
# de Wyke, Richard (fl. by 1315; d. by 1336). 403/438,
# 418. Father of Albreda, John, and Walter.
#
# Inhabited 418. Subsidy 2s. (1327), 3s, (1332).
# Citizen 1327. 5
# *le Kyke.
#
# ~~, Albreda daughter of (7. by 1336). From her father:
# part 418. Related to Richard (de) Wyke.
#
# ~~, John son of (fl. by 1336). From his father: part
# 418. Related to Richard (de) Wyke.
#
# ~~, Walter son of (fl. by 1336). Part 418. Related to
# Richard (de) Wyke.
#
# (de) Wyke, Richard (/1. 1336, by 1364). 418, parts 424-
# 6. Married (by 1336) Agnes. Father of Agnes. Related
# to Albreda, John, and Walter, children of Richard de
# Wyke (ff. by 1315; d. by 1336).
#
# Inhabited 418. Subsidy 8s. (1340). Citizen by
# 1361.
#
# ~~, Agnes daughter of (/1. by 1364, by 1377). Married
#
# (by 1364) Vincent Merlawe.
#
# ~~, Agnes wife of (/1. 1336).
#
# Wykeham, Nicholas (ff. 1372; d. by 1407). 807-9. Re-
# lated to William of Wykeham.
#
# Sometime canon of king’s free chapel of Bosham,
# prebendary of Appledram (Sussex), rector of Witney
# (Oxon), master of God’s House, Portsmouth, master
# of St. John Baptist Hospital, Portsmouth, canon of
# Salisbury, prebendary of Bedwyn (Wilts) and of Tims-
# bury in Romsey Abbey, master of St. Cross, arch-
# deacon of Wilts, prebendary of Walton in Bosham,
# and canon of Howden (Yorks) (Emden Oxford to
# 1500, pp. 2112-13).
#
# de Wykham, Ralph, junior (fl. 1327; d. by 1337). Part
# 473-5.
#
# Inhabited part 473-5. Dyer. Subsidy 5s. (1327),
# 5s. (1332).
#
# de Wykham, Richard (fl. 1336). ?Part 707-8. Married
# (by 1336) Rossya.
#
# ~~, Rossya wife of (/1. 1336).
#
# Wykys, John (jf, 1496-1513). Part 622-3. Married (by
# 1501) Isolde Bramdene wife and widow of Stephen
# Bramden(e).
#
# Ale offences 1500-1 (CR); owned silverware 1513
# (CR). Esquire 1501 (CR).
#
# ~~, Isolde wife of, v. Isolde Bramdene wife and widow
# of Stephen Bramden(e).
#
# Wylby, William (ff. 1435-58). Part 414,
#
# Inhabited Tanner Street aldermanry (1435-6)
# and Colebrook Street aldermanry (1446). Subsidy
# assessment lost (1435), 2d. (1436), 2d. (1446).
#
# Wylbye, Thomas (fl. by 1469). ?153H,
#
# Inhabited ?153H.
#
# Wyld, Richard (/2, 1482). 103/109-11,
#
# Wyld, Thomas (/?. 1462-3). Part 238,
#
# Wylde, Nicholas (fl. 1433). ?Part 841,
#
# Wylde, Roger (fl, 1464-92). 2335, 493, part 496, Mills
# at Coytebury, 497/502G,
#
# Inhabited St. Mary’s Tanner Street parish. ?F uller.
# Subsidy 12d. (1464). Auditor for commons 1476-7
# (CA); collector 1476-7; aulnager 1477-8 (CA); bailiff
# 2 (1478-9), bailiff 1 (1480-1); aulnager 1481-2
# (CA); mayor 1487-8.
#
# de Wylehale, Roger, v. Roger de Wyn(e)hale.
#
# Wylkinsone, Richard, v. Richard Wylkynson(e).
#
# Wylkyn, Alice, v, Alice Wylkyn alias Alice atte Nas-
# crofte wife and widow of John Wilkyn.
#
# Wylkyns, James (fl. 1558). 878.
#
# Wyikyns, John (fl. 1417). 738.
#
# Wylkynson(e), Richard (ff. 1490-1501). Wylkinsone.
# Part 103/109-11, parts 473-4,
#
# de Wylleforde, Roger, v. Roger de Wyvelesford alias
# Roger the chaplain.
#
# Wylliamson, Gerard, v. Garitte Wyllyamson alias Gerard
# Shomaker.
#
#
#
# BIOGRAPHICAL REGISTER 1395
#
# Wyllyamson, Garitte alias Gerard Shomaker (fl. 1462-
# 97). Gerard Wylliamson. From his ?relative John Wil-
# lyamys: parts 486.
#
# Corveser, shoemaker.
#
# Wyllyamson, Harmon (fl. 1492; d. 1512). Herman Wil-
# liamson, 151-2, 162. Possibly related to Thomasine
# Williamson alias Thomasine Harmon.
#
# Tailor. Steward of fraternity of St. John the Bap-
# tist 1498-9 (CA); bailiff 2 (1503-4); collector 1504-5
# (CA); bailiff 1 (1506-7). See HRO Wills B, s.a. 1512.
# *Herman Williame.
#
# Wyl(Il)yngham, Robert (fl. 1427-46). 184.
#
# Inhabited High Street aldermanry. Sold spices
# 1427 (CRB); had fruit, soap, almonds, salt, pepper,
# rice, and herrings carted from Southampton 1439-40
# and 1443-4 (Brokage). Subsidy 2s. 6d. (1435), 2s. 8d.
# (1436), 4s, (1446). Chamberlain 1431-2 (CA); bailiff
# 1 (1433-4); mayor 1439-40.
#
# Wyllys, Thomas (fl. 1524-32). Part 344. Possibly related
# to Agnes Will.
#
# Inhabited Colebrook Street aldermanry. Subsidy
# 4d., goods (1524). Yeoman 1532.
#
# Wylmer, Thomas (f1. 1485-6). 460.
#
# Wylot, Walter (ff. 1438-41). Part 266.
#
# Wylton, William (/7, 1465-71). 268.
#
# Rector of St. Peter Whitbread.
#
# Wylya’, John (fl. 1453-4). 166.
#
# Wylyngham, Robert, v, Robert Wyl(1)yngham.
#
# Wymonds, William (/2. 1589-1604). 574.
#
# Woollen draper.
#
# Wyn, Elizabeth (fl, 1549). ?Part 125.
# *Ellis Wyn.
#
# Wyn, Ellis (d. by 1590), v. following.
# *Elizabeth Wyn.
#
# ~~, heirs of (fl. 1590). 541-3.
#
# Wyn, John (fl. 1590). Part 645.
#
# Wynburn, John (fl. by 1460), v. following.
#
# ~~, Maud wife of (fl. by 1460). 1076.
#
# de Wyncestre, Richard, v. Richard de Wync(h)estre.
#
# Wynchester’, William, v. William Wynchestre.
#
# de Wynchestr’, Roland (fl. by 1352). ?Part 1111.
# *Roland de Oddingesel(e).
#
# Wynchestre, John (fl. 1386-91). From his brother John
# (de) Byketon: 182, ?part 987.
#
# Wynchestre, Juliana (fl. 1489). 278.
#
# Wynchestre, Richard, lord of Otterbourne (fl. by 1380),
# v, sub following.
#
# **Richard de Wync(h)estre.
#
# tWynchestre, William (ff. 1380-96). Wynchester’. 492,
# 493, 584, 624, 630, 763. Son of Richard Wynchestre,
# lord of Otterbourne. Married (by 1384) Joan. Possibly
# related to Simon le Drapir alias Simon of Winchester.
#
# Ale offences 1388-93 (CR). Citizen 1389.
# t~ ~, Joan wife of (1. 1384-96).
# tde Wync(h)estre, Richard (fl. by 1364; d. by 1386). Part
#
# 50-6. Married (by 1364) Isabel. Father of Thomas de
# Wynchestre.
#
# Accused of trying to dispossess Hugh (le) Cran of
# manor of Otterbourne 1380 (Cal Pat R 1377-81,
# p. 577).
#
# *kRichard Wynchestre, lord of Otterbourne.
#
# t~ ~, Isabel wife of (ff. by 1364).
#
# tde Wynchestre, Thomas (f1. 1386-7). 606. Son of Richard
# de Wync(h)estre.
#
# de Wyndleshore, William (/7. 1309; d. by 1318-19). 113.
# Married (by 1309) Margery widow of Philip de Can-
# dev(e)re.”
#
# ~~, Margery wife of, v. widow of Philip de Candev(e)re.
#
# Wyneflod, William (fl. 1350-4). Wynesflode. Part 566.
#
# Mayor 1350-1, MP 1353, 1353-4.
#
# de Wyn(e)hale, Roger, of Winchester (fl. 1294; d. by
# 1317). de Wylehale. ?Part 983-4, part 989, part 1088.
#
# Skinner.
#
# Wyneman, Thomas, v. Thomas Wynman.
#
# atte Wynerd, Gedfrey, v. Godfrey atte Wyn(h)erd.
#
# atte Wynerde, Richard, v. Richard atte Wyn(h)erde.
#
# atte Wynerthe, John (fl. by 1351-2). From his ?relative
# Richard atte Wyn(h)erde: part 903.
#
# Wynesflode, William, v. William Wyneflod.
#
# de Wyngeham, Hugh (/7. c.1170). 645-7/669-70E.
#
# Wyngham, Ralph (/7. 1507; ?d. by 1554). Wingham. 193,
# part 266, 428, 679, part 681. Probably married (by
# 1554) Margaret Wingham.
#
# Inhabited High Street aldermanry. Labourer 1507-
# 37 (SJR). Subsidy 6d., wages (1515-16), 12d., goods
# (1524). Beadle 1524 (Black Book, 138).
#
# ~~, Margaret Wingham ?widow of (fl. by 1554). From
# her ?husband: 428.
#
# de Wyngham, Hugh, v. Hugh de Wingham.
#
# Wyngood, Clement (/1. 1366-93). Wynnegoud. 399.
#
# Innkeeper 1385-93 (CR); deposited white alum
# 1366, discharged woad-waste 1386 (CR); owned fisca
# 1387 (CR).
#
# Wynhale, James, of Winchester (fl. c.1400; ?d. by 1449).
# Wynnale. 421, 474, Mills at Coytebury, 721. Married
# (by 1418) Alice. Father of Thomas.
#
# Inhabited 421. Fuller; had cloth woven outside
# liberty 1402 (CR); one of petitioners for freedom to
# manufacture cloth outside walls 1411 (Black Book,
# 28). Subsidy 2s. 6d. (1430), 2d. (1435), 2d. (1436).
#
# ~~, Alice wife of (ff. 1418-21).
#
# ~ ~, Thomas son of (fl. 1446-9). From his father: 421.
#
# Inhabited 421. Subsidy 4d, (1446).
#
# de Wynhale, Roger, v. Roger de Wyn(e)hale.
#
# atte Wyn(h)erd, Godfrey (fl. 1335, by 1364). 71, Mar-
# ried (by 1335) Juliana.
#
# Subsidy 2s. (1340).
#
# ~~, Juliana wife of (fl. 1335).
#
# atte Wyn(h)erde, Richard (fl. 1317-43). 76, part 903.
# Probably related to John atte Wynerthe.
#
# winchesterP-106.jpg
# 1364 BIOGRAPHICAL REGISTER
#
# Tailors (cont.)
# Simon,
# William the king’s tailor.
# le Tainturor, Geoffrey (fl. by 1285; d. by 1305). Geof
# frey the dyer. 472, Married (by 1305) Joan. Father of
# Alice.
# ~~, Alice daughter of (fl. by 1305). From her father:
# 472.
# ~~, Joan wife of (fl. by 1305).
# Taker, Walter (ff. 16th cent.). 135.
# Talbot, Geoffrey (fl. 1370-1; d. 1381). 142. Married (by
# 1380) Goude widow of John Donetoun.
#
# Brewer 1379-80 (CR); entered guild merchant
# 1370-1 (CA); ale offences 1379-81 (CR); sold fustian
# 1380 (CR); owned pigsty 1379-80 (CR). Executed as
# rebel 1381.
#
# ~~, Goude wife of, v. widow of John Donetoun.
#
# Talbot(t), Richard (/1. 1405-6, by 1413-14), 948, 951-2,
# part 963, 980, part 1061.
#
# Tame, Thomas (fl. 1455-96). Part 311-12.
#
# Tapster 1473-96 (CR); entered liberty of city
# 1481-3 (CA). On commission to enquire on whose
# land gaol was situated 1455 (Cal Pat R 1452-61,
#
# * p. 223).
# de Tame, Thomas (fl. by 1336). ?Part 707-8. Married
# (by 1336) Joan.
# Skinner.
# ~~, Joan wife of (fl. by 1336).
# Tane, Elizabeth, v. ?daughter of Roger Steele.
# Tane, John (fl. 1569; ?d. by 1588). 969. ?Married (by
# 1588) Elizabeth Tane ?daughter of Roger Steele.
# Labourer.
# ~~, Elizabeth ?widow of, v. ?daughter of Roger Steele.
# Tangle, Richard (fl. 1459). 240.
# Citizen.
# Tannare, John (fl. 1402-3, 1404-5). 495.
# *J. Tanner.
# *John Tannere (fl. 1417).
# Tanners, v. Ambrose,
# John,
# Luke,
# Peter,
# Roger.
#
# Tanner, Cristina (fl. 1449-56). From her ?relative wit
#
# liam Webbe: part 446.
# Tanner, J. (fl. by 1417). 158.
#
# *John Tannare.
#
# *John Tannere (fl. 1417).
# Tanner, Nicholas, v. Nicholas Tanner(e).
# Tanner, Richard (fl. by 1423-4). 1039, ?1052.
#
# Tanner, Richard (fl. 1573; ?d. by 1604). 10, 12, 13, part
#
# 238, 710.
#
# Tanner, Roger (fl. 1416-17; d. by 1418-19). ?Part 1032,
#
# ~~, widow of (fl. by 1418-19). From her husband:
#
# Ppart 1032.
#
# Tanner, Thomas (fl. 1382). 804B.
# *Thomas Lucas.
#
# Tanner, William (fl. 1417). 540.
#
# le Tanner John, of Hogheleslane (d. by 1334). 210B.
# Married (by 1334) Edith de Saundon.
#
# *John le Tavernir.
#
# ~~, Edith de Saundon widow of, v. wife and widow of
# Robert de Saundon(e).
#
# le Tanner, John (fl. 1336-45), v. John le Tanner(e).
#
# le Tanner, Nicholas (ff. by 1352). 488. Possibly related
# to Roger the tanner.
#
# Tannere, John (fl. by 1372, 1419). From his brother
# Nicholas Tanner(e): 44, ?628. Also held: part 987.
#
# Rector of Winnall by 1372, clerk 1418-19.
#
# Tannere, John (fl. 1417). 175-8.
#
# *John Tannare,
# *J. Tanner.
#
# Tanner(e), Nicholas (fl. by 1372; d. by 1413). 44, 259,
# part 266, 490, 532-3, 2559, 628, 646. Brother of
# John Tannere (fl. by 1372, 1419).
#
# Vintner 1388, 1400-10 (CR); bought wine at
# Southampton 1396, sold red wine 1400 (CR); ale of-
# fences 1386-1409 (CR); sold 2 cloths 1394-5 (E101/
# 344/10); John Felbrygge of Wherwell owed him share
# £40 (1409) (Cal Pat R 1408-13, p. 126); owned wool
# 1391 (CR). Citizen by 1372; bagman 1394-5 (CA);
# MP 1396-7; bagman 1397-8 (CA); aulnager 1398
# (Fine R 1391-9, p. 231); coroner 1399 (Cal Pat R
# 1396-9, p. 515); MP 1400; collector 1402 (CR);
# bailiff 1 (1405-6); bagman 1406-7 (CA); supervisor
# of King’s Mill 1409 (Black Book, 10).
#
# le Tannere, Drew (fl. 1335). Part 519-20, 527-8.
#
# le Tanner(e), John, of Wherwell (fl. 1336-45). AF4,
# ?part 711. Married (by 1336) Isabel.
#
# ~~, Isabel wife of (fl. 1336).
#
# le Tannere, Thomas (fl. 1402). ?Part 1022.
#
# le Tannur, Adam (fl. 1241, by 1243). ?Part BF1, BF2.
# Uncle of Walter Rufus. Possibly related to Alan le
# Tanur.
#
# * Adam Croche.
# le Tannur, Arnold/Hernold (fl. before 1294). 484, 1039.
#
# \wfe Tannur), Savery (d. by 1248-51), v. sub Emma
#
# ter of Adam Croche.
# 9 Gervase and John ?children of (/1. 1248-51). BF6.
# le Tanur, Alan (ff. 1241-5). BF1, BF3, BF 4. Married (by
#
# 1241) Albreda/Aubrea. Father of Robert. Possibly re-
# lated to Adam le Tannur.
# Inhabited BF3 (1241) and BF4 (1241).
# ~~, Albreda/Aubrea wife of (fl. 1241-5).
# ~~, Robert son of (fl. 1244-5). BF3, BF4.
# le Tanur, Luke (fl. 1248-51). ?Part 380. Married (by
# 1248-51) Mary.
# **Luke the tanner.
#
#
#
# BIOGRAPHICAL REGISTER 1365
#
# ~~, Mary wife of (fl. 1248-51).
# le Tapenar, Richard (/1. 1264-6, 1266-73). 274.
# Tapeners, v. Osbert,
# Reginald,
# Walter.
# Tapener, John (fl. 1454). 1004.
# *John Cooke (fl. 1440-72).
# le Tapenyr, Gilbert (f2. 1294). 2997.
# le Tapenyr, Reginald (/2. by 1284; d. by 1330). 730-1. -
# Married (by 1304) Maud.
# ~~, Maud wife of (71. by 1304, by 1305).
# le Tapenyr, Sewald (fl. 1294). 399. Possibly related to
# Reginald the tapener and Walter the tapener.
# Tapeser, Nicholas (fl. 1395-6, 1405). 218.
# Made cushions and bankers 1400, 1404 (CR).
# Tappestere, Margaret (fl, 1414). 769.
# ?Innkeeper.
# Tapster, Humphrey (fl. 1515-16). ?Part 35-9.
#
# Inhabited ?part 35-9, Servant. Subsidy 6d., wages
# (1515-16).
#
# Tavernar, John, v, John le Tavernir.
# Tavernare, John (fl. 1417). 355,
# Taverner, Raymond (fl. 1413, 1417-18). 181.
#
# Had cloth woven outside liberty 1413, sold cloth
# without licence 1414 (CR).
#
# Taverner, Robert (fl. 1417-35). Part 197, 213.
#
# ?Inhabited part 197, Subsidy 8d, (1430).
#
# Taverner, Roger (fl. 1380-9). Part 160.
#
# Inhabited part 160. Vintner 1380, 1382-7, mer-
# chant 1385, tapster 1380-9 (CR); sold wine 1380,
# 1382, ale offences 1382-6, bought wine 1385 (CR);
# bought white herrings 1385, sold cloth 1386 (CR).
#
# le Taverner, John, v. John le Tavernir.
#
# le Taverner, Thomas (fl. 1286; d. 1297). 2337-9.
# *Thomas the vintner.
#
# ~~,widow of (fl. 1297-1301). From her husband:
# 2337-9.
#
# le Tavernir, John (ff. 1314; 2d. by 1351-2). Tabernar,
# Tavernar, le Taverner, ?Part 210.
#
# Inhabited ?part 210. Exported hides through
# Southampton 1332-3 (E122/137/7). Subsidy 12d.
# (1327). Accused of attacking Hyde Barton 1314 (Cal
# Pat R 1313-17, pp. 145-6).
#
# *John le Tanner (d. by 1334).
#
# Tavy, Gaylard (fl. 1367-8). 618-19,
#
# Tawyers, v. Alexander,
#
# Ivo.
#
# Taylardes, Thomas (fl. 1498, 1506-7). Part 263.
#
# Taylefer, William, v. William Taillefer.
#
# Tayllepres, William (fl. by 1248-50). 682, 694-5.
# *Master William.
#
# Tayllour, Henry alias Henry atte Swan(e) (fl. 1365; ?d.
# by 1409). Taillour. 78, 253, 257, 538. Married (by
# 1401) Alice wife and widow of John Broun (fl. by
#
# 1356; d. by 1401).
#
# Innkeeper 1365 and 1400-1, brewer 1365-7 and
# 1370-80, tapster 1379 (CR); ale offences 1365-1403
# (CR); sold oats, charcoal, bikeman 1366, baked horse
# bread 1366, bought fustian 1380 (CR); sold 6 cloths
# 1394-5 and 1 cloth 1398-9 (E101/344/10, 12);
# owned stray pig 1367, owned bull-stall and pigsty
# 1393 (CR). Collector 1376-7, bagman 1376-7, 1378-9
# (CA); auditor for commons 1386-7 (CR); bagman
# 1394-5, 1397-8 (CA); citizen 1401.
#
# *Henry Taillour.
#
# ~~, Alice wife of, v. Alice wife and widow of John
# Broun (fl. by 1356; d. by 1401).
#
# Tayllour, Peter (fl. 1473-4). Part 103/109-11.
#
# Tayllour, Simon, v, Simon Trotet, alias.
#
# le Tayllur, Nicholas (/7. 1261, c.1266). Part 1104,
#
# Deprived of office of chief cook at Cathedral Priory
# 1261 (Cal Inq Misc i, no. 261).
#
# Taylor, Edmund (fl. 1459-61). Part 266. Possibly related
# to Walter Taylor.
# Taylor, James (fl. 1557). 877.
# Taylor, John (fl. 1393-1436), v. John Chalk(e)pole, alias.
# Taylor, John alias John Wyse (fl. 1449-71). Part 140.
# ?Inhabited part 140, Tailor. Subsidy 8d, (1464).
# Taylor, John (fl. 1496-7). 238.
# Taylor, John (f2. 1539-40), v. John Taylo(u)r.
# Taylor, John (fl. 1590-1602). 379.
# Shoemaker.
# Taylor, Maurice, v. Maurice Taillour.
# Taylor, Philip (fl. 1630). 117.
#
# Shoemaker.
#
# Taylor, Ralph (f7. 1520-1). Part 645. Possibly related to
# Edmund Taillour and Thomas Taillour.
#
# Taylor, Richard (fl. 1451, 1455-6). Part 486. Possibly
# related to Thomas Taylour.
#
# Probably participated in disturbances in Winchester
# associated with Cade’s rebellion 1451 (KB9/109).
#
# Taylor, Richard (fl. 1496-7, 1523-4), v. Richard Taillour.
# Taylor, Thomas (fl. by 1507). 77.
# Taylor, Walter (fl. 1465-96). From his ?relative Edmund
# Taylor: part 266. Also held: part 484,
# Taylor, William, v, William Taylo(u)r.
# Taylour, Denis (f7. 1417). Part 112.
# Taylour, John (fl. 1430). ?Part 182-3. Possibly related
# to Lawrence Taylour.
# Inhabited ?part 182-3. Servant. Subsidy 8d. (1430).
# *John Warner (fl. 1410-36).
# Taylo(u)r, John (fl. 1539-40). 2442, 2447, 482.
# Taylour, Lawrence (fl. 1458-9). Part 182-3, Possibly re-
# lated to John Taylour.
# Inhabited part 182-3.
# Taylour, Robert, v. Robert Taillour.
# Taylour, Thomas (fl. 1430-71). Part 486. Possibly related
# to Richard Taylor (fl, 1451, 1455-6).
#
# winchesterP-17.jpg
#
#
# 1166
#
# ? -1407, strengar 142
# (CR); discharged woad waste 1389 (CR); sold 9
# cloths 1394-5 (E101/344/10); bought linen clot!
#
# BIOGRAPHICAL REGISTER
#
# oan.
# From her first husband
# ° 4): 799. Later married (by
#
# 799. Married (by
#
# 1396 (CR); imported wine through Southampton illiam Mayhew. -
# 1426 (E122/184/3). Subsidy 2s. (1435). 66-7B. Married (by 1331)
# *John Bele (jl. 1435-77). atherine daughter of Ralph Bolle.
#
# ?Bole, John, v. John Dole.
#
#
#
#
#
# . Tenter ground E.
#
# d Porter (/l. 1454). Part 854.
# Possibly related to Roger Porter.
#
# Bole, Richard (fl. 1446; d. 1490), v. Richard Bo(o)le.
# Bole, Thomas, v. Thomas Bo(o)le.
# Bole, William (fl. 1435-58), v. William Bol(I)e.
# Bole, William (fl, 1515-16). ?Part 35-9.
#
# Inhabited ?part 35-9. Servant of John Jamys alias
# ohn Wynna Subsidy 6 wage 5-16
#
#
#
#
#
# ohn Forst.
#
# of Southampton.
# ughter of John Forst.
# de Bolendon, Roger, v. Roger de Bolyndon(e).
#
# Boleret, William - 2
# . 82/89,
# 90, part 384. Married (by 1305) Alice.
# Ry aici 1 oii
# de Bolindon, Robert, v. Robert de Bol(1)yndon.
# de Bolin Roger .
# R).
#
# 6-7B, part 496.
# Father of Catherine wife of William Bollok. Possibl
# related to Richard Bolle and his sister Isabel.
#
# i art 496. Subsidy 8d. (1327).
# Qf ~ catherine auger o (by 1985 Married (by
# 1331) Willi
# [Pyro Ricaes by 1831, 1840) °%56-18 Brother of
# Isabel. Possibly related to Ralph Bolle.
#
# Inhabited Buck Street and Colebrook Street alder-’
#
# m idy 5s, (1340).
# x by 1331, 21365). 266-7B. Pos,
# sibly related to Ralph Bolle.
# Z cold 1365 (CR).
#
# a Bol(l)e, William (fl. 1435-58). Part 400B, 444-5, 456,
# 497/502B. Possibly related to John Bele (fl. 1435-
# 77).
# Inhabited Tanner Street aldermanry. Had woa
# carted from Southampton 1439-40 (Brokage). Sub-
# sidy 12d. (1435), 14d, (1436), 12d. (1446).
# de Bollindon, Robert, v. Robert de Bol(I)yndon.
#
# i Winchester Staple 1364-7 (C47/33/8)
#
#
#
#
#
#
#
#
# Afr~, Catherine wite v. daughter of Ralph Bolle.
# Bollou obert, v.
#
#
#
# . de
#
# olindon, de Bollindon, de Bolyngdon, From his rela-
# tive Roger de Bolyndon(e): 420, 2442, 461, 476-7.
# Also held: 437. Married (by 1322) Catherine. Father
# of Agatha.
#
#
#
#
#
#
#
# 37. Related to
#
#
#
# 50-6C, 114, part 386-7, 410, 411, 412, 421, 429,
# 430. Married (by 1377) Joan. Later married (by 1380)
# Maud Mayheu/Mayhew daughter of Ralph Mayh(e)u.
# Inhabited soke (1380), 411 (1397), ands 1379).
# Dyer 1364-6, appraiser of woad (CR);
# 1361-
# 7 (CR); ale offences 1361-97, deposited woad-gore
# 1366 (CR); sold 29 cloths 1394-5 (E101/344/10);
# traded in corn 1391-2 (CR). Collector 1357-8 (CA);
# bailiff 2 (1362-3), bailiff 1 (1365-6), mayor 1368-
# 9, 1385-6. In 1378 he was counted among the
# rich merchants of the suburb (Cal Close R 1377-81,
#
# P1373; d. by 1380).
# Discharged woad-waste 1373 (CR).
# aud Mayheu/Mayhew daughter
#
#
#
# Bolt, Alice, v. Alice Bolt widow of John T(o)umber.
#
# Bolt, Cecilia, v. Cecilia daughter of William Bolt.
# Bolt, Ellen, v. ?widow i e).
#
# arso:
#
# +Bolt, John (fl. 1451-2). From his father Richard Bolt(e):
#
# 275-6, 429, 435, 448, 465, 667.
# Chaplain.
# Bolt, Nicholas (fl. 1507-8). Part 197. *
#
# Bolt, Rich:
# Bolte. 82/89,
#
# 226, 275-6, 429, 435, parts 448, 465, ?part 496,
# 2498, 593, part 800. Married (by 1365) Emma. Later
# married (by 1365) Alice (Bolt) widow of John
#
# BIOGRAPHICAL REGISTER
#
# T(o)umber. Father of Richard Bolt(e), Cecilia Bolt,
#
# and Agnes, Alice, and Joan.
# Inhabited 465 y 1366/ayerby 1366;
#
# discharged woad-waste 1386 (CR); sold 63 cloths
# 1394-5 and 10 cloths 1398-9 (E101/344/10, 12);
# owned linen and woollen cloth 1404 (CR). Assesso:
#
# of fines 1375 (CR); collector 1377-8, 1378-9 (CA);
# bailiff 2 (1380-1), bailiff 1 (1385-6); joint warde
#
# of SJH 1390-1 (CR); mayor 1395-6, MP 1397-8,
# mayor 1405-6.
#
#
#
#
#
#
# P by 1377). Part 448
# . Alice (Bolt) widow o
# John T(o)umber.
# |. by 1369, by 1377).
#
#
#
#
#
# Part 448.
#
# de Badesle widow of John (de) Badesle.
# 1377). Part 448.
#
# William Bolt and Alice Bolt: 593. From his mother:
#
# +Bolt(e), Richard (ff. 1402; ?d. 1430-5). From his parengs]/()
#
# zz) i Ve:
#
# 1167
#
# Bolyndon, Richard, v. Richard (de) Bolyndon.
# . ?767. Probably related
# . 1327-32).
# Inhabited ?767. Subsidy 4s. (1340).
# Part 800. Probably related
# to Roger de Bolyndon(e).
#
# . 2767. Probably related
# to Agnes de Bolyndon and possibly to John (de)
# Bolyndon.
#
# Inhabited 2767. Subsidy 2s. (1327), 3s. (1332).
# . 767, Married (by
# 1334) Joan. Possibly related to John de Bolyndon (fl.
# 1327-32).
# Inhabited 767. Subsidy 12d. (1340).
# *John Bolyndon (fl. by 1377).
#
#
#
#
#
#
#
# 5). 226. Related to Emma ..9
#
# { ?Part 976, 2997.
#
# ** Agnes Bolyngdon.
# de Bolyndon, Robert, v. Robert de Bol(1)yndon.
#
# 429, 2433, 435, 448, 465. Also held: 275-6, 659,
# 660, 662, 667. Married (by ?1417: CRB) Margare de
# daughter of Richard Compton. Later married (b Bolendon, de Bolindon. : .e , 476-
#
# 1428: CRB) Ellen Bolt. Father of John Bolt (fl.
# 1451-2).
#
# Inhabited 429 (1430) and perhaps earlier lived in
# Gold Street. Vintner 1410-11 (CR); petitioned for
# freedom to manufacture cloth outside walls (Black
# Book, 27-8); merchant 1428 (CRB); exported cloth
# through Southampton 1427 (E122/184/3); sold
# cloth 1427, bought woad and teasels at Southampton
# 1428 (CRB); ale offences 1404-14 (CR); hired a cel-
# lar in Southampton 1428 (CRB); owned cloth 1428
# (CRB); owned basins, pewter, armour 1433 (CR).
# Subsidy 16s. 8d. (1430). Alderman of Gold Street
# 1407 (CR); citizen 1409, bailiff 1 (1412-13), MP
# 1415, mayor 1416-17, 1418-19, MP 1419, 1425-6,
# mayor 1427-8.
#
# +~~, Ellen Bolt wife and widow of (fl. 1428 (CRB); ?d.
# by 1451). From her husband: 2429. Mother of John
# Bolt (fl. 1451-2).
# Inhabited 2429. Subsidy 20d. (1435).
# ~~, Margaret wife of, v. Margaret daughter of Richard
# Compton.
# oy le Bolte, William, v. William Bolt.
#
# Bolton, George (fl. 1582). 422.
# (a) Bolton, John (fl. 1512-24). Part 645.
# Inhabited St. John’s in the Soke parish. Subsidy 2s.,
#
#
#
# e city.
# *John (de) Bolyndon.
#
#
#
#
#
# 7, ?part 707-8, part 800. Married (by 1310) Eve.
# Related to Robert de Bol(l)yndon and probably to
# John de Bolyndon (fl. 1294).
#
# r for repair of chapel in castle
# 1305-6 (E101/368/21); supplied queen’s buttery
# temp. Edward I (E101/371/1/11). Accused of attack-
# ing Hyde Barton 1314 (Cal Pat R 1313-17, pp. 145-6).
# Citizen by 1310.
#
#
#
# ** Agnes wife of Richard (de) Bolyndon.
# Bolyngdon, Thomas, of Buckinghamshire (fl. 1417-20).
# Byllyngdon. From his grandmother Alice atte Wer(e)
# alias Alice Haywode wife and widow of Thomas Hay-
# wode: 400, 491. Son of Cristina daughter of Thomas
# Haywode.
# de Bolyngdon, Robert, v. Robert de Bol(l)yndon.
# Bomo(u)r, John (fl. 1411). ?Part 943, 945, ?part 1081.
# Inhabited ?part 1081.
# *John Somour.
# Bonar, John (fl. 1481-2). 1076.
# Bond, John (fl. 1491-1514). Bounde. Part 238.
# Imported dye and ?iron filings through Southamp-
# ton 1491-1514 (E122/142/11, E122/143/1).
# Bond, Roger (fl. 1570-1604). 118.
# Bond, Thomas, v. Thomas Bond(e).
# Bonde, John, of the soke (fl. 1590-8). 830, 874.
# Notary public.
# Bond(e), Thomas (fl. 1513-37). Bounde. 681.
# Inhabited High Street aldermanry. Exported tanned
# calfskins and kerseys through Southampton 1514
# (E122/143/1). Subsidy 6d., wages (1515-16).
#
# winchesterP-82.jpg
#
#
#
#
#
#
# 1316 BIOGRAPHICAL REGISTER
#
# Parsons (cont.)
#
# Stephen parson of St. Mary’s at West Gate.
# See also under individual churches and rectors.
#
# Parson, Agnes (fl. 1480-3). From her ?relative Joan
# Parson: part 267. Possibly related to John Parson
# (fl. 1456-69).
#
# Parson, Joan (fl. 1473-4). From her ?relative John Par-
# son (fl. 1456-69): part 267. Possibly related to Agnes
# Parson.
#
# Parson, John (fl. 1437-8, c.1445). Part 486.
#
# Parson, John, junior (fl. 1456-69). Part 267, 269. Pos-
# sibly related to Joan Parson and Agnes Parson.
#
# Parson, John (fl. 1511-12, 1529-30). Part 238, 679.
#
# Beadle 1524 (Black Book, 138). Perhaps two
# people here.
#
# Parsone, John (fl. by 1459). 185.
#
# Partrich, John, v. John Partryge.
#
# Partrych, John, v. John Partryge.
#
# Partryge, John (fl. 1435-54). Partrich, Partrych, Perd-)
# rech’, Pertrech’. 2481, 463.
#
# Inhabited 2481 (1435-6) and 463 (1446). Fuller
# 1454 (CR); had woad, alum, oil, and paving stones
# carted from Southampton 1439-40 and 1443-4
# (Brokage). Subsidy 6d. (1430), 6d. (1435), 6d.
# (1436), 2s. 8d. (1446). Citizen 1454 (CR).
#
# Parvus, Robert (fl. by c.1230). 370. Married (by c.1230)
# Eleanor.
#
# ~~, Eleanor wife of (fl. by ¢.1230).
#
# Parvus, William, v. William Petit, alias.
#
# Parvy, John (/1. by 1312, by 1318). 367.
#
# Parys, Joan (fl. by 1446-7). 77.
#
# Parys, John, of the city of Winchester (fl. 1434-67). 77,
# 290, 318.
#
# Inhabited 77 (1435-6, 1446) and ?90 (by 1457-
# 8). ?Dyer (Wedgwood, 659; cf. 90). Subsidy 16d.
# (1435), 18d, (1436), 5s. (1446). Exempted offices of
# bailiff 1438 (Black Book, 75). MP 1446-7, mayor
# 1447-9, MP 1449-50, 1452-3, 1453-4.
#
# Parys, Nicholas (fl. 1377; d. by 1424). ?Part 1022. Mar-
# ried (by 1385~6) Alice. Father of John.
#
# Miller at Durn Gate and baker 1377 (KB9/107).
#
# ~~, Alice wife of (fl. by 1385-6; d. by 1424). Mother
# of John.
#
# ~~, John son of (fl. by 1385-6; d. 1424). ?Part 1022.
#
# Pase, Cornelius (fl. 1485-1500). 2371,
#
# Paskyn, Thomas (ff. 1554). 227.
#
# le Passager, William (fl. c.1300; d. by 1313). Part 139.
# Married (by 1313) Agnes. Father of Richard.
#
# ~~, Agnes widow of (fl. by 1313). From her husband:
#
# part 139.
# ~~,Richard son of (fl. 1313). From his father: part
# 139.
#
# Passelawe, Robert (fl. by 1347). 206. Married (by 1347)
# Joan.
#
# ~~, Joan wife of (fl. by 1347).
#
# Passion, Edmund (fl. 1599). 607.
# Vintner.
# Pasterane, Robert (1. by 1481-2). 153H.
# Patchford, Richard, v. Richard Pac(c)heford.
# Pateneye, William (fl. 1398). 267.
# Patient, Nicholas (fl. 1590-1604). Part 130/132.
# Patington, John (fl. by 1465-6). 7162.
# Patri(c)k, John (fl. 1370-1, by 1417). Patryk(e). 8, 190.
# Married (by 1417) Alice.
# Fishmonger 1371-1404, merchant 1403, tapster
# 1387 (CR); entered guild merchant 1370-1; ale of-
# fences 1387-1411, sold oysters 1390 (CR); bought
# victuals 1372 (CGR); sold 19 cloths 1394-5 (E101/
# 344/10); traded in woollen cloth 1403 (CR); sold
# cloth 1406 (CRB); owned pigsty 1393 (CR).
# ~~, Alice wife of (fl. 141 T)s
# Patryk(e), John, v. John Patri(c)k.
# Pauke, John (fl. 1457). 799.
#
# “ Fellow of Winchester College 1457.
#
# Paulinus the clerk alias Paulinus the scrivener (fl. 1264-
# 5; 2d. by 1294). 682, 2914. Father of Felicia.
# ~, Felicia daughter of (fl. 1294). From her father:
#
# ¥ 682.
#
# Paulinus the scrivener, v. Paulinus the clerk, alias.
#
# le Paumer, v. Thomas called.
#
# le Paumer, John (fl. 1272, by 1320), v. John Moraunt,
# alias.
#
# le Paumer, John (fl. 1286; ?d. by 1320), v. John le Pal-
# mer(e).
#
# le Paumer, John (fl. 1294-1338), v. John (le) Palmere.
#
# le Paumer, Thomas, v. Thomas le Palmer(e).
#
# Pauncefot, Richard, v. Richard Paunsefot.
#
# Paunsefot, Richard (fl. 1360s, 1374). Pauncefot. Part
# 238/678. Sheriff of Hants 1374. Probably related to
# the Fromund family.
#
# le Paveler, Robert (fl. 1243). Part Castle Ditch.
#
# Paver, Charles, v. Charles Pav(i)er.
#
# Paviar, William, v. William Pavier.
#
# Pav(i)er, Charles (fl. 15 15-42). Part 497/502.
#
# PInhabited part 497/502. Subsidy 12d., goods
# (1515-16), 4d., goods (1524).
# *Charles Fuller.
#
# Pavier, Charles v. Charles Pavyer. (fl. 1590).
#
# Pavier, Frances, v. ?daughter of William Pavier.
#
# Pavier, William, of Winchester (fl. 1551-68; ?d. 1582).
# Paviar. Parts 486, 499, Mills at Coytebury. Probably
# married (by 1489) Alice. Probably father of Frances
# Pavier and Charles Pavyer (fl. 1590).
#
# Inhabited parts 486. Fuller. See HRO Wills B, s.a.
# 1582.
#
# ~~, Alice widow of (fl. 1589). From her ?first hus-
# band William Pavier: part 486. Later married (by
# 1589) William Collens. Mother of Frances Pavier and
# Charles Pavyer (fl. 1590).
#
# ~ ~, Frances Pavier ?daughter of (fl, 1589). Part 486.
#
#
#
# BIOGRAPHICAL REGISTER 1317
#
# de Pavilly, William (ff. 1215; d. by 1228). Mint.
#
# Pavyer, Charles (fl. 1548). 483-4.
#
# Pavyer, Charles (fl. 1590). Pavier. From his ?father Wil-
# liam Pavier: 499. Also held: part 486.
#
# Pawlett, John (fl. 1628). 933, 938, 940.
#
# Pax, Richard (f. 1571). 108/104.
#
# Weaver.
#
# Paxe, William (fl. 1590). 463-4.
#
# Pay, William (fl. 1504; d. 1523-4). 268, part 304. Pos-
# sibly related to Agnes Paie.
#
# Inhabited High Street aldermanry. Subsidy 12d.,
# goods (1515-16).
#
# ~~, widow of (fl. 1524-5). From her husband: 268.
#
# Payce, John (fl. 1590-1604). Paice. 85, 86, part 197,
# 251-2/270, part 288, 454-7, 564-5.
#
# Haberdasher.
#
# Payce, Richard (fl. 1584-1604). Paice. 208-7, 275, 277,
# 372-3. Possibly related to Thomas Payce.
#
# Payce, Robert (fl. 1570). Part 266.
#
# Carpenter.
#
# Payce, Robert (ff, 1584-1604). Paice. Part 197, part
#
# 670, 671, part 678. ;
# Haberdasher.
#
# Payce, Susan (fl. early 17th cent.). 67-8.
#
# Payce, Thomas (fl. 1504). 203-7. Possibly related to
# Richard Payce.
#
# Paye, John (fl, 1467-8). Part 311-12.
#
# Payge, Emma, v. wife and widow of William Page I.
#
# Payge, William (fl. 1523-4). Part 197.
#
# Paymour, John (fl. 1402-18). 126.
#
# Payn, Andrew, of Kings Somborne (fl. by 1320, 1335).
# 195, 591/601/603-4D, part 618-19, part 620, part
# 621, 622-3. Married (by 1320) Alice.
#
# ~~, Alice wife of (fl. by 1320, 1335).
#
# Payn, John (fl. by 1358). 510.
#
# Payn, John (fl. by 1604). 707-8.
#
# Payn, John (ff. 1390; d. by 1417), v. John Payn(e).
#
# Payn, Richard (fl. 1351-2). Part 197.
#
# Inhabited part 197.
# Payn, Robert (fl. c.1260-70). ?Part 772-80, 2937.
# Payn, Stephen (fl, 1417). Part 182-3.
#
# Taverner.
#
# Payn, Thomas (fl. by 1313, 1337). 638, part 645-7/
#
# 669-705, ?part 1014. Married (by 1313) Joan.
# Citizen by 1313.
# ~~, Joan wife of (fl. by 1313, 1337).
# *Joan Wranne.
#
# Payn(e), John (fl. 1390; d. by 1417). 213, 215-16, 268,
#
# 559.
# Rector of Michelmersh 1408, clerk 1410. Described
# as master 1408.
# ~~, executors of (fl. 1417). 213.
# Payne, Robert (fl. 1570). Part 264.
# Carpenter.
# Payne, ... (fl. 1589). Part 266.
#
# la Payne, Cristina (fl. ?by 1279). 765. Probably related
# to Emma la Payne. :
#
# la Payne, Emma (fl. ?by 1279). 765. Probably related to
# Cristina la Payne.
#
# Paynter, John (fl. 1511-30). Part 197, part SJH.
#
# Warden of sick at SJH.
#
# Paynter, Thomas (fl. 1541). Part 140.
#
# Payntor, Alice (fl. 1512-13). Part 484.
#
# Payntour, John (ff. 1394). 866.
#
# Inhabited 866.
#
# Paywell, Isabel, v. wife and widow of John de Twyford
# alias John le Hattere.
#
# Pece, William (fl. 1452-1503). Parts 963, 1053. Father
# of Constance.
#
# ~~,Constance daughter of (fl. 1496-1503). Married
# (by 1496) Anthony White.
#
# Pedelevere, John (fl. 1351-2). ?Part 717. Possibly related
# to William Pedelyvere.
#
# Pedelyvere, Walter (fl. 1384-1402). From his father Wil-
# liam Pedelyvere: 226.
#
# Pedelyvere, William (fl. by 1365; d. by 1384). From his
# ?relative John Pedelevere: part 717. Also held: 226,
# part 238/678, 771. Married (by 1365) Cecilia. Later
# married (by 1381-2) Agnes. Father of Walter Pedely-
# vere and Eleanor.
#
# Brewer 1380, ale offences 1380-3 (CR). Citizen
# 1381-2.
#
# ~~, Agnes wife and widow of (fl. 1381-2; d. by 1408).
# ?From her husband: 226. Probably later married (by
# 1398) Richard Gould(e).
#
# ~~, Cecilia wife of (fl. by 1365; d. by 1381-2).
#
# ~~,Eleanor daughter of (fl. 1384-1402). From her
# father: 226.
#
# Pedilworth, Robert, v. Robert Pedylworth.
#
# Pedylworth, Robert (fl. 1458-91). Pedilworth, Pydel-
# worth. 290, 372, 388.
#
# Tapster 1473 (CR); entered liberty of city 1477-8
# (CA).
#
# Peers, John (fl. by 1417). 579.
#
# Peg, Joan (fl. 1437-8). Part 238.
#
# Pehoun, Ralph (fl. by 1294). ?463.
#
# Peitt, Richard (fl. 1545). 214.
#
# Pek, Hugh, v. Hugh Puke.
#
# le Peliper, Godwyn, of London (fl. by 1318). Part 1128.
#
# le Peliter, William (fl. by 1346, by 1374). 328. Married
# (by 1346) Alice.
#
# ~~, Alice wife of (fl. by 1346).
#
# le Pelter, John (fl. by 1367). 735.
#
# Pemerton, Christopher (fl. 1590-3). 657, 666. Probably
# related to George Pemerton.
#
# Minor canon of the cathedral.
#
# Pemerton, George (fl. 1594-1604). Mr. Pemmerton.
# From his ?relative Christopher Pemerton: 657, 666.
# Also held: 655, 656.
#
# Pemmerton, Mr., v. George Pemerton.
#
# winchesterP.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# i aaa
#
# ie ee a
#
# sito
#
# sci lic cL NaN RA NRTA
#
# |
# ;
# %
# :
# .
# 5
# =
# 2
# 3
# &
# @
# 2
# 2
# =
#
#
#
# mm ™ . | = = _ iz mE a=
#
# INTRODUCTORY NOTE
#
# i. GENERAL PRINCIPLES AND ARRANGEMENT
#
# THIS biographical register is essentially an alphabetical guide to the holders of property in Win-
# chester who occur in the gazetteer forming Part II of this work, It includes a small number of indiv-
# duals not mentioned in the gazetteer, but who have been identified in other sources as relatives or
#
# servants of property-holders. It does not contain references to instances where individuals have been
#
# cited in the notes to the gazetteer entries as witnesses for the purpose of dating transactions. Such
# references are covered by the General Index at the end of the work. The register of property-holders is
# divided into three sections: names of persons (pp. 1143-1397); uncertain or illegible names, apart from
# those where the first letter of the surname is legible (pp. 1397-8); and institutions (pp. 1398-1403).
#
# Entries in the register concerning property-holders begin with a headform of the individual’s
# -name.in,bold and references to an individual’s entry are always by means of this headform. All
# cross-references are given in Roman type. Entries concerning individuals who are not recorded as
# property-holders have the headform in Roman type. /talic type is used for cross-references concerning
# unusual name-forms from late manuscripts, for example
#
# John Persevalsoudam, v. Percival Sowdon.
#
# Property-holders are defined as persons or institutions who had any interest in a property in
# Winchester. In practice it is often impossible to define the precise nature of that interest. Tenants,
# sub-tenants, and the owners of quit-rents are thus given the same weight as landlords.
#
# The entries are arranged so as to reflect nuclear family groups rather than families extended over
# several generations or through intermarriage. Successive generations and collateral relationships
# within families can be traced from the references to relatives in each entry; all such relatives have
# their own entries where their properties are listed; the more complex relationships between families
# are also expressed in the series of family trees in Appendix II. All entries concerning individuals
# who are included in a family tree are defined in the margin by a dagger sign (T).
#
# Properties held are defined by the numerical or an abbreviated form of the verbal heading to the
# entries in the gazetteer. These always appear in bold.
#
# ii. THE IDENTIFICATION OF INDIVIDUALS
#
# So far as possible, all the information recorded about any individual has been gathered into a
# single entry in the register. There are two difficulties associated with this process: the separation of
# information concerning individuals who were contemporary and had the same name; and the colla-
# tion of information about individuals who were known by more than one name. Both these prob-
# lems have been tackled in the same way by the comparison of all the recorded personal details con-
# cerning the individual(s). An initial presumption of identity may be strengthened or rejected by
# consideration of such circumstantial evidence as occupation descriptions, recorded wealth and social
# status, and the geographical distribution of properties held in Winchester. In establishing identities,
# a period of no more than fifty years’ recorded activity has been allowed for each individual, except
# where there can be no doubt that a person was active for longer.
#
# The numerals I, I, etc. are used to distinguish individuals only where successive generations of
# father and son had the same name. When it is necessary to distinguish individuals with the same name
#
# ‘Much of this introduction is based on notes provided by Alexander Rumble, who devised many of the principles applied in the
# biographical register.
#
# —_
#
# winchesterP-25.jpg
#
#
#
# 1202
#
# ACorbyn, John (fl. 1285-1300). ?Part 857.
# orbyn, Michael (fl. 1480-3). 126.
# sie a Walter (f7. 1314-20). ?840, ?part 848.
# ~, wife of (fl. 1314).
# Cordewanir, Henry (fl. by 1310, by 1352). le Cord-
# waner. AF5, ?part 711. Possibly related to Alexander
# le Cordwaner.
# Described as master by 1310.
#
# ordiwaner, Godfrey (fl. 1271). ?Part 691-3.
# orduan’, Robert (fl. by 1290). ?Part 687,
# Cordwaner, Alexander (fl. by 1335-6). ?Part 711.
#
# “* Possibly related to Henry le Cordewanir.
#
# le Cordwaner, Henry, v. Henry le Cordewanir.
# Cor(e)ham, Roger (jf. 1590-1604). 320, 737-8, 758,
# 783, 784-7, 788-9, 801. Probably related to William
# Coreham.
# A well-known recusant (Rosen, 84).
# Coreham, William (fl. 1604). From his ?relative Roger
# Cor(e)ham: 320, 783, 784-7. Also held: 321, 340-3.
# Esquire 1604.
#
# BIOGRAPHICAL REGISTER
#
# Spicer 1406 (CR); traded in spices 1401, 1407,
# 1409 (CR); traded in wax, quicksilver, herrings 1410,
# wax and black soap 1413, and wax and resin 1416
# (CRB). Bagman 1410-11 (CA); bailiff 2 (1411-12);
# attorney for Titchfield Abbey 1414, 1416 (CR);
# bailiff 1 (1416-17), mayor 1418-19.
#
# ~~, Amicia wife and widow of (fl. by 1419, by 1430).
# Later married (by 1430) Thomas Hayne (fl. 1424-30).
# le la Corner, John (fl. ?by 1284-5). 2493.
# \Cornew, Ralph (fl. 1464; d. 1493). 72-3, part 197, part
# 326.
#
# Inhabited St. Lawrence’s parish. Barber; entered
# liberty of city 1465-6 (CA). Subsidy 2s. (1464). Ex-
# cused office of bailiff, constable, and chamberlain
# (sic) 1468 (Black Book, 101); chamberlain 1477-8
# (CA).
#
# le Cornewalays, Walter, v. Walter de Parkham alias
# Walter le Cornewalays alias Walter of Cornwall.
#
# le Cornewalch, Walter, v. Walter de Parkham alias
# Walter le Cornewalays alias Walter of Cornwall.
#
# Corehambury, William, v. William Cobhambery aie NY Cornewaleis, Ralph (fl. by late 13th cent., by 1340).
# /
#
# William le Clerk.
#
# Corf, John, v. John Corf(f)e.
#
# Corfe, Alice (fl. 1558). From her ?relative John Corf(f)e:
# part 1037.
#
# Corf(f)e, John (fl, by 1539-40; 2d. by 1554). Corf, 994,
# ...
#
# Smyth, Ralph (fl. by 16th cent.). 136.
# Smyth, Richard, of Southampton (fl. 1458-65). ?1030,
# 21034,
#
# Merchant. Burgess of Southampton 1465.
#
# Smyth, Richard (fl. 1506-17). From his ?relative Thomas
# Smyth (fl. by 1457): 151-2. Also held: 2495.
#
# Smyth, Richard, of Avington (fl. 1536). 151-2.
#
# Smyth, Richard, of Littleton (fl. 1536). 151-2.
#
# Smyth, Richard, of Winnall (fl. 1563). 989,
#
# ‘Yeoman,
#
# Smyth, Robert, junior, of New Alresford (fl. 1385,
# 1401-2). Part 508,
# Smyth, Robert, of South Gate (fl. 1462). 639.
#
# Smyth, Roger (fl. 1467-1501). Part 103/109-11.
# ?Inhabited part 103/109-11. Tapster 1495-1501
# (CR). Counterfeiting money 1467 (Cal Pat R 1467-
# 77, p. 53).
#
# Smyth, Roger (fl. 1529-30). Part 264.
#
# Smyth, Thomas (fl. 1376-7; d. by 1421). Smith. 267,
# 436, 449, 457, 458, 622-3. Married (by 1387) Alice.
# Later married (by 1421) Maud.
#
# ?Inhabited 458. Fuller 1392-c.1400, draper 1412-
# 17, tapster 1403-4, brewer 1414 (CR); entered guild
# merchant 1376-7, fee payer 1378-9 (CA); sold 96
# cloths 1394-5 and 46 cloths 1398-9 (E101/344/10,
# 12); sold wool 1402, had cloth woven outside liberty
# 1410-11 (CR); sold cloth outside liberty 1413
# (Zaehnsdorf ii, 98); sold cloth 1421 (CR). Alderman
# of Tanner Street 1377-8 (CA); bailiff 2 (1382-3);
# chamberlain 1386-7 (CR); bailiff 1 (1387-8); collec-
# tor 1390-2 (CR); mayor 1397-8, 1400-1, 1412-13.
#
# ~~, Alice wife of (ff. 1387; d. by 1421).
#
# ~~, Maud widow of (fl. 1421, by 1423-4). From her
# husband: 449, 458.
#
# Smyth, Thomas (fl. by 1457). 151-2. Possibly related to
# Richard Smyth (ff, 1506-17).
#
# Smyth, Thomas alias Thomas Broker, of Priors Dean (fl.
# 1447; d. by 1472). 1004, 1028. Married (by 1447)
# Margery.
#
# ~~, Margery wife and widow of (fl. 1447-72). From
# her first husband Thomas Smyth alias Thomas Broker:
# 1028, Later married (by 1472) John Cooke (fl. 1440-
# 72).
#
# Smyth, Thomas (fl. 1460-70). Part 238.
#
# Weaver.
#
# Smyth, Thomas (fl. 1469-78). 854,
# *Thomas Smyth (fl. 1504-10).
#
# Smyth, Thomas, of Worthy Mortimer (fl. 1504-10). Part
# 859. Married (by 1504) Joan.
#
# Husbandman 1510.
# *Thomas Smyth (fl. 1469-78).
#
# ~~, Joan wife of (fl. 1504-10).
#
# Smyth, Thomas (fl. 1505-24), v. Thomas Smith (fl.
# 1505-24).
#
# Smyth, Thomas (fl. 1535-42). 515.
#
# Cooper.
#
# Smyth, Thomas (ff. 1536). 151-2. Possibly related to
# William Smyth (fl. 1536).
#
# Smyth, Walter alias Walter Clement (ff. 1446-78). Part
# 140, part 326.
#
# ?Inhabited part 140, Smith; made iron bands and
# hooks 1446-7 (CA). Subsidy 6d. (1446), 2s. (1464).
#
# Smyth, William (fl. 1432-56). Part 633-4, 636.
#
# ?Inhabited part 633-4. Entered liberty of city
# 1432-3 (CA); had oil carted from Southampton
# 1439-40 (Brokage); ale offences 1454-5 (CR). Sub-
# sidy 2s, (1435), 3s. (1436), 8s. (1446). Mayor 1442-3,
# 1449-50, 1455-6.
#
#
#
# BIOGRAPHICAL REGISTER 1351
#
# Smyth, William (fl. 1477-85). Part 238, part 681.
#
# Labourer.
#
# Smyth, William (fl. 1536). 151-2. Possibly related to
# Thomas Smyth (fl. 1536).
#
# le Smyth, John, v. John de Twyford alias John (le) Smyth.
#
# le Smyth, William (fl. 1863-4). Part 141.
#
# Inhabited part 141.
#
# Smythe, Felicia (fl. 1418). 515.
#
# Smythe, John (fl. 1417). 680.
#
# le Smythe, John, de Ichene (f7. by 1354). From his aunt
# Lucy ?widow of Geoffrey Spure: part 496. Married
# (by 1354) Isabel.
#
# ~~, Isabel wife of (fl. by 1354).
#
# Snel, Adam (fl. by 1310). Part 559-60. Married (by
# 1310) Osanna daughter of William de Candevere.
#
# ~~, Osanna wife of, v. daughter of William de Candevere.
#
# Snel, John (fl. 1365; d. by 1380), v. John Snel(l).
#
# Snel, John (fl. ?by 1375, 1388; 2d. by 1432), v. John
# Snel(1) alias John Redhede.
#
# Snel, Robert, of Leckford (fl. 1399). 411. Probably re-
# lated to Roger Snel(l) and John Snel(1) alias John
# Redhede.
#
# Snel, Roger, v. Roger Snel(I).
#
# Snell, Alice, v. wife and ?widow of John Snel(l) alias
# John Redhede.
#
# Snel(1), John (f7. 1365; d. by 1380). 218, 2223, 630, 633.
# Married (by 1372) Alice. Possibly related to John
# Snel(1) alias John Redhede.
#
# Pnhabited 630. Merchant 1365, skinner by 1376-7,
# brewer 1373-4 (CR); bought timber 1371 (CR). Alder-
# man of Gold Street 1374 (CR); bailiff 2 (1376-7).
#
# ~~, Alice wife and widow of (fl. by 1372; d. by 1380).
# From her first husband John Snel(l): 633. Later mar-
# ried (by 1380) Edmund Pycard.
#
# Brewer 1379 (CR); ale offence 1379 (CR). Legacy
# to chapel of SJH (SJR s.a. 1395-6).
#
# Snel(1), John alias John Redhede (fl. ?by 1375, 1388;
# 2d. by 1432). 2223, 398, 411, 437, 713. Married (by
# 1388) Alice Snell. Probably related to Robert Snel
# and Roger Snel(1) and possibly to John Snel(1), from
# whom he may have acquired 223.
#
# Tapster 1403-4 (CR); entered liberty of city
# 1397-8 (CA); ale offences 1403-5 (CR); sold bread
# 1393 (CR); sold 10 cloths 1398-9 (E101/344/12);
# sold cloth 1405, 1408-9, and a weaver’s loom 1423
# (CRB). Collector 1397-8 (CA); citizen 1399, MP
# 1402; churchwarden of St. Pancras 1403, bailiff 1
# (1403-4).
#
# ~~, Alice Snell wife and ?widow of (fl. 1388, 1432).
# ?From her husband: 411.
#
# Snell, John (fl. 1429-51). ?Parts 973, part 976.
#
# Snel(I), Roger, of the soke (/l. 1368-99; ?d. by 1417).
# From his ?relative John Snel(1) alias John Redhede:
# 411, Also held: 738, 781, 928. Married (by 1395-6)
# Alice. Probably related to Robert Snel.
#
# Inhabited 928. Draper 1370-?82 (Cal Pat R 1369-
# 70, p. 341; Cal Close R 1381-5, p. 43); grocer 1377-9
# (KB9/107; Cal Close R 1377-81, p. 180); merchant
# 1380 (CRB); traded in cloth 1380 (CRB); sold madder
# 1387 (CR); sold 10 cloths 1394-5 (E101/344/10);
# Richard Toky of London, grocer, owed him £12
# (1391) (Cal Plea & MR 1381-1412, p. 214).
#
# ~~, Alice wife of (d. by 1395-6).
#
# Snell, William (ff. 1515-17). 2611-13.
#
# Snelling, John (fl. 1389; ?d. by 1417). Snellyng. 333.
# Married (by 1389) Alice widow of Richard Nor(t)h-
# ampton (CR).
#
# Innkeeper between 1389 and 1390-7, merchant
# 1390, tapster 1389-90 (CR); ale offences 1391-7
# (CR); bought hay and stockfish 1390, sold stockfish
# 1390 (CR). Collector 1394-5, 1397-8 (CA).
#
# ~~, Alice wife of, v. wife of Richard Nor(t)hampton.
#
# Snellyng, John, v. John Snelling.
#
# Sno(o)ke, Alice (fl. 1604-12). 23, 243.
#
# Snowe, ... (fl. 1471-2). Part 238.
#
# Snyllyng, Agnes (fl. 1458-61). Slyllyng, Stillyng. Parts
# 238. Possibly related to Joan Skyllyng alias Joan
# Skyllynter.
#
# Solas, James (fl. 1423, c.1437). 678.
#
# Inhabited High Street aldermanry (near 678). Fish-
# monger 1423-33 (CR); bought fish 1429 (CR); ale
# offences 1423-33 (CR). Subsidy 11s. (1430), 2s. 6d.
# (1435), 2s. (1436). Bailiff 1 (1431-2), MP 1435.
#
# Solas, John (fl. by 1453-4), v. following.
#
# ~~, Joan wife of (fl. 1453-4). 229.
#
# Soldrop, William, v. William Suldrop.
#
# atte Sole, William (fl. 1401-17). 573.
#
# Helier 1401-17, tapster 1408-10 (CR); bought
# woollen cloth 1401 (CR).
#
# Sombourn(e), John (fl. 1377-1402). ?Part 1021.
#
# Weaver 1377 (C47/60/59); sold 1 cloth 1398-9
# (E101/344/12).
#
# Sombourne, Margery (fl. 1432). ?Part 992.
#
# Sombourne, Robert (fl. 1390-1407). Part 264. Married
# (by 1390) Joan.
#
# Fishmonger 1403-7 (CR).
#
# ~ ~, Joan wife of (fl. 1390).
#
# Sold oysters 1390 (CR).
#
# de Somb(o)urne, William (f7. 1340-60). 431, ?part 983.
#
# Inhabited 431, Subsidy 3s. (1340).
#
# le Somenour, Richard, v. Richard de Folye, alias.
#
# le Somenour, Robert (fl. 1318-19). 113.
#
# *Robert le Waleys alias Robert de Warneburne.
#
# le Somenour, Roger (fl. by 1343; ?d. by 1372). Part
# 559-60. Married (by 1343) Joan.
#
# ~ ~, Joan wife of (fl. by 1343).
#
# Somer, Agnes, v. relative of Henry Somer (fl. by 1316,
# by 1334).
#
# Somer, Catherine, v. Catherine (Somer) daughter of
# Mark le Fayre.
#
# winchesterP-98.jpg
# 1348 : BIOGRAPHICAL REGISTER
#
# Simond, John (cont.)
# William Simond(e)s, Thomas Symonds, Peter Symonds,
# and Mrs. Symonds.
#
# Bailiff 2 (1539 ~40).
#
# Simond, Thomas (1. 1395-1405). 497/502E.
#
# Simond(e)s, William (ff, 158 1-1604). Symond, Sy-
# mond(e)s, Symons. 157, 158, 159, 345, 366-7, 386-
# 7, 388, 389-91, 392, 428, 429, 584-6, 608, 978,
# 1067. Probably related to John Simond, Peter Sy-
# monds, Thomas Symonds, and Mrs. Symonds.
#
# Gentleman 1590.
#
# Simons, William, of Hursley (fl. 1589). 824,
#
# Clerk.
#
# Simpson, Noah (f2. 1604). Part 772-80,
# Sinay, John (fl. by 1283-5, by 1321). Synay. Part 637,
# part 640/643,
# de Sireburn, William (ff. 1231-2). Part 1099,
# Described as master.
# de Sireston, Thomas, v, Thomas (de) Syreston.
# Skarlet(t), Henry, v, Harry or Henry Scarlet.
# Skathebold, William, v, William Scathebold.
# Skeche, John (1. 1493-1519). 35-9.
#
# - Tapster 1500 (CR); entered liberty of city 1493-4,
# 1495-6, fee payer 1506-7 (CA); farmed guild mer-
# chant 1512-13 (CA). Auditor for commons 1495-6,
# chamberlain 1499-1501, auditor for commons 1500-1 ‘i
# 1506-7 (CA) ; bailiff 2 (1509-10), bailiff 1 (1511-12).
#
# Skinners, v. Benedict,
# Henry,
# Martin,
# Mathias/Matthew,
# Reginald Spryngot alias Reginald the skinner,
# Roger,
# Sampson,
# Seman le Skynnere alias Seman atte Castelle.
# Skinner, Joan (ff. 1624). 822.
# Skinner, John (/1. 1417). 379,
# Dyer.
# Skinner, John (fl. 1551; d. 1585), v. John Skynner (fl.
# 1551; d. 1585).
# Skryvenour, Thomas (fl. 141 7). 781.
# Skutt(e), John (f1. 1542-5). 873; 884,
# Inhabited 884,
# Skylling, John (72. 1506-13). 557-8.
# Skylling, Michael (fl. 1429-31), v, following.
#
# Merchant 1431 (CRB). Owned bedclothes, furni-
# ture, and a messuage in Andover 1431 (CRB). Attor-
# ney for Cathedral Priory 1429 (CR).
#
# ~™, sister of (fl. 1457-8). Part 681.
# Skyllyng, Joan alias Joan Skyllynter (@. 1462-4). From
# her ?relative Agnes Snyllyng: part 238,
# Skyllynter, Joan, v. Joan Skyllyng, alias.
# Skynner, John (fl. 1391-1415), v, John Skynner(e).
# Skynner, John (fl. 1440-7), 495.
# *John Simeney.
#
# — si SU EEEEEIEEREEREEEEeEeEREEEEE
#
# Skynner, John (fl. 1523-30). 416. Possibly related to
# John Skynner (fl. 1551; d. 1585) and to Thomas
# Skynner (fl. 1495-1515; ?d. 1515).
#
# Farmed guild merchant 1523-5 (CA). Auditor for
# commons 1528-9, steward of fraternity of St. John
# the Baptist 1529-30 (CA).
#
# Skynner, John (fl. 1551; d. 1585). Skinner. 94-5, 96-7,
# 126, 131, 332, parts 414, 2415, 416, 417, 418, 419,
# 458. Married (by 1562) Edborowe. Father of Eliza-
# beth. Possibly related to John Skynner (fl. 1523-30).
#
# ?Inhabited 416-19. Alderman 1573.
#
# ~~, Edborowe wife of (fl. by 1562).
#
# ~~, Elizabeth daughter of (fl. by 1585, by 1587). From
# her father: ?415, 416, 2417-18, 2458. Married (by
# 1587) Hugh Danby.
#
# ~~, heirs of (fl. 1590-1604). 561.
#
# Skynner, Richard,.v, Richard Skynner(e).
#
# Skynner, Thomas (fl. 1397-1415). Part 486, 497/502E.
#
# Skynner, Thomas (fl. 1495-1514; ?d. 1515). 315, 416,
# 449. Possibly related to John Skynner (fl. 1523-30).
#
# ?Inhabited Hyde Street aldermanry, ?Fuller; en-
# tered liberty of city 1504-5, entered guild merchant
# 1506-7 (CA); farmed guild merchant 1512-13 (CA).
# ?Subsidy 6s., goods (1515-16). Bailiff 2 (1510-11),
# bailiff 1 (1513-14). Possibly the Thomas Skynner of
# St. George’s parish who d. 1515 (HRO, Wills B).
#
# Skynner, . . . (fl. 1447-8). Part 486.
#
# le Skynner, Valentine, v. Valentine Hammond, alias.
#
# fle Skynner, William (ff. 1329-30). 766. Married (by
# 1329) Joan Springot sister of Reginald Spryngot alias
# Reginald the skinner. ;
#
# ~ ™, Joan Springot wife of, v. sister of Reginald Spryngot
# alias Reginald the skinner.
#
# Skynner(e), John (fl. 1391-1415). Part 264, Probably
# related to Richard Skynner(e).
#
# Innkeeper 1405 and 1410-13, dyer 1412-15 (CR);
# bought table-cloths 1391, ale offences 1412-14, sold
# oil 1414 and cloth 1415 (CR).
#
# Skynner(e), Richard (fl. 1386, 1396-7). Part 264. Prob-
# ably related to John Skynner(e).
#
# Sold fur 1386 (CR); sold 24 cloths 1394-5 (E101/
# 344/10).
#
# *Richard Skynnere.
#
# Skynnere, Richard (fl. 1422). 825.
# *Richard Skynner(e).
#
# le Skynnere, Roger (fl. 1319-20). 219,
#
# le Skynnere, Seman alias Seman atte Castelle (fl. by
# 1311, 1340). Seman the skinner. AF3, 40, 241, part
# 1088, Married (by 1315) Amy. Father of Walter.
#
# Inhabited AF3. Skinner; lent share 100 marks to
# Crown ¢,1340 (Cal Pat R 1338-40, p. 450). Subsidy
# 6s. (1327), 7s. (1340). Accused of admitting strangers
# to liberty 1312 (Cal Pat R 1307-13, p. 534). Bailiff 1
# (1320-1).
#
# ~~, Amy wife of (fl. by 1315).
#
#
#
# BIOGRAPHICAL REGISTER 1349
#
# ~~, Walter son of (fl. by 1332). Part 659. Married (by
# 1332) Joan ?daughter of Nicholas le Lyn(ge)draper.
#
# ~™, Walter son of, Joan wife of, v. Joan ?daughter of
# Nicholas le Lyn(ge)draper.
#
# Skyp, William (f1. by 1368). 664.
#
# Slade, John, of the soke (/. mid-16th cent.). 820.
#
# de Slappelegh , Thomas (fl. 1343-7). Slapye. ?Part 724-6,
# 936. Married (by 1343) Isabel. Probably father of
# Alice Sloppele.
#
# ~~, Alice Sloppele ?daughter of (f. by 1362, by 1363-
# 4). From her ?father: ?936. Also held: ?part 724-6,
# *Alice Wolmylk. 7
#
# ~~, Isabel wife of (ff. 1343-7).
#
# Slapye, Thomas, v. Thomas de Slappelegh.
#
# Sleute, John (fl. 71430, 1442). Slo(w)te. 218.
#
# Inhabited 218. Subsidy 6d. (1430), 1d. (1435),
# 1d. (1436).
#
# *John Slowt.
#
# Slider, Richard (ff. 1590). Part 344,
#
# Inhabited part 344,
#
# Sloppele, Alice, v. ?daughter of Thomas de Slappelegh.
#
# Slote, John, v, John Sleute.
#
# Slowt, John (fl. by 1417). 696,
#
# *John Sleute.
#
# Slowte, John, v. John Sleute.
#
# Slugge, John (/. 1493), Part 352.
#
# Slyllyng, Agnes, v. Agnes Snyllyng.
#
# Smale, Thomas (fl. 1382-1418). 62, 68, 247, 283, part
# 300-3/329, part 309-12, 319. Married (by 1394)
# Edith.
#
# Butcher 1382-1418 (CR); master of butchers 1409
# (Black Book, 18); sold 4% cloths 1398-9 (E101/344/
# 12); bought salt 1404, sold tallow 1413, bought linen
# cloth and kerchiefs 1418 (CR). Collector 1391 (CR)
# and 1394-5 (CA); bailiff 1 (1401-2); constable 1404
# (CR); MP 1405-6, citizen 1406; alderman of High
# Street 1406-7 (CA); MP 1406-7; constable of High
# Street 1407 (CR); mayor 1414-15; auditor for 24
# (1418) (CR).
#
# ~~, Edith wife of (7. 1394).
#
# ~~, widow of (fl. by 1435). From her husband: 309.
#
# Smart, Henry, v. Henry Smart(e).
#
# Smart, Roger, v. Roger Smart(e).
#
# Smart(e), Henry (fl. 1436; d. 1489). 229, 275-6, 327,
# 336, parts 400, 429, 435, 448, 463, 465, 554, 597,
# 642, 2656, 658, 2660-5, 7667, ?part 687. Related to
# William Ussher(e). Probably related to John Saunder.
#
# Inhabited 661-5. Subsidy 20d. (1436), 18d. (1446),
# 8s. (1464). On committee to enquire on whose land
# gaol was situated 1455 (Cal Pat R 1452-61, p. 223);
# excused both offices of bailiff 1455 (Black Book, 85);
# MP 1455-6; negotiated with Bishop Waynflete over
# city mill 1467 (Black Book, 89); mayor 1471-2, MP
# 1472-3; auditor for 24 (1476-8) (CA).
#
# Smart(e), Roger (fl. 1394-5, 1417). 470.
#
# Sold 2 cloths 1394-5 and 12 cloths 1398-9 (E101/
# 344/10, 12).
# Smay, John (fl. by 1285). 2124.
# Smiths, v. Alexander,
# Emma widow of the smith, \
# Henry,
# Mark,
# Ralph,
# Richard,
# Walter,
# William.
# Smith, Bartholomew (fl. 1627). 828-9.
# Smith, Christopher (ff. by 1604). Part 151-2.
# Smith, Margaret (/1, 1430-48). Part 446.
# Inhabited part 446, Subsidy 4d. (1430), 1d.
# (1435), 1d. (1436).
# Smith, Nathaniel (ff. 1590-1604). Part 344,
# Inhabited part 344,
# Smith, Percival (/7. 1458-69). 972, 1061.
# Smith, Richard (f. 1417). 136.
# Smith, Robert (fl. 1397-1429), v. Robert Gyffard,
# alias.
# Smith, Robert (ff. 1459). 241.
# Smith, Thomas (fl. 1376-7; d. by 1421), v Thomas
# Smyth (fl. 1376-7; d. by 1421).
# Smith, Thomas (fl. 1505-24). Smyth, Part 645.
# Sold timber 1505-6 (CA).
# Smith, Thomas (ff. 1580). 50-62P.
# Smith, William (f1. 1590; d. by 1604). 439-40, 458.
# Labourer.
# ~~, widow of (fl. 1604). From her husband: 439-40.
# le Smith, William, v. William (atte) Hole, alias.
# Smyth (fl. 1529-30). ?Part 1022.
# Smyth, Adam, of Oxford (fl. 1391; d. c.1408). Surtel.
# 137, 138, 372, 567-8. Married (by 1408) Agnes.
# Sold horse-shoes 1403 (CR). Citizen by 1398,
# described as master by 1398.
# ~~, Agnes widow of (ff. 1408-17). From her husband:
# 138, 372, 567-8.
# ~~, executors of (fl, 1408-10). 188, 567-8.
# Smyth, Agnes (fl, 1482-3). Part 238,
# Smyth, Henry (/1. 1400, by 1417). 684,
# Brewer 1400 (CR); ale offence 1400 (CR).
# Smyth, Joan (fl. 1472-3). 25,
# Smyth, John (ff. by 1333, 1340), v. John de Twyford
# alias John (le) Smyth.
# Smyth, John (1. c.1346; d. by 1383). 144, Married (by
# c.1346) Cristina.
# Soap-maker 1362-75, shop-keeper 1365-6, brewer
# 1351 (CR).
# ~~, Cristina wife of (ff. c.1346; d. by 1383).
# Symth, John (f2. 1394-5, 1404), v. following.
# Probably weaver who sold 14 cloths 1394-5 and 2
# cloths 1398-9 (E101/344/10, 12). Killed his wife
# 1404 (CR).
